# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

import time

from math import sqrt

# %matplotlib notebook

# %%
# %install_ext https://raw.githubusercontent.com/SiggyF/notebooks/master/pep8_magic.py
# %load_ext pep8_magic
# Out:
# /usr/local/lib/python3.4/dist-packages/IPython/core/magics/extension.py:47: UserWarning: %install_ext` is deprecated, please distribute your extension as a python package.
#   "as a python package.", UserWarning)
# Installed pep8_magic.py. To use it, type:
#   %load_ext pep8_magic
# The pep8_magic extension is already loaded. To reload it, use:
#   %reload_ext pep8_magic

# %%
path = '../../data/test_images/'
filenames = next(os.walk(path))[2]

# %%
timestr = time.strftime("%Y%m%d-%H%M%S")

path1 = '../../data/test_images/'
path2 = '../../data/inp_images/'
i = 1
for filename in filenames:
    filepath = os.path.join(path1,filename)
    img = cv2.imread(filepath,cv2.IMREAD_COLOR)
    filtered_img = cv2.bilateralFilter(img,9,150,150)
    
    #filepath = os.path.join(path2, str(i) + '-raw.png')
    #cv2.imwrite(filepath, img)
    filepath = os.path.join(path2, str(i) + '-bfilt.png')
    cv2.imwrite(filepath, filtered_img)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-285-df1462754ea3> in <module>()
#       7     filepath = os.path.join(path1,filename)
#       8     img = cv2.imread(filepath,cv2.IMREAD_COLOR)
# ----> 9     filtered_img = cv2.bilateralFilter(img,9,150,150)
#      10
#      11     #filepath = os.path.join(path2, str(i) + '-raw.png')
#
# error: /home/ayush/dev/opencv_download/opencv/modules/imgproc/src/smooth.cpp:3145: error: (-215) (src.type() == CV_8UC1 || src.type() == CV_8UC3) && src.data != dst.data in function bilateralFilter_8u

# %% [markdown]
# # Point Set Generation for fish images

# %% [markdown]
# ## GrabCut algorithm
# Iterative graph-cut segmentation problem using GMMs to model the foreground and background

# %%
# %%pep8
def mark_background(img):
    """
    Automatically mark background (top left corner is a good idea)
    :param img: input image
    """
    img_height,img_width,num_channels = img.shape
    
    # window of size not exceeding 1/10 of the image dimesnion; max 60 pixels
    max_win_size = 150
    win_height = int(min(img_height/10,max_win_size)-1)
    win_width = int(min(img_width/10,max_win_size)-1)
    
    #print(win_height)
    #print(win_width)
    
    extraction = img[0:win_height,0:win_width]
    mean = np.mean(extraction,(0,1))
    var = np.var(extraction,(0,1))
    
    background_threshold = 0.08
    ratio = np.mean(np.divide(np.sqrt(var),mean))
    
    
    print(mean)
    print(var)
    
    
    mask = np.empty((img_height,img_width),dtype = img.dtype)
    mask.fill(cv2.GC_PR_FGD)
    
    selection_threshold = np.minimum(2*var,0.2*mean)
    print(selection_threshold)
    
    
    
    diff_channel1 = np.abs(img[:,:,0]-mean[0])<selection_threshold[0]
    diff_channel2 = np.abs(img[:,:,1]-mean[1])<selection_threshold[1]
    diff_channel3 = np.abs(img[:,:,2]-mean[2])<selection_threshold[2]
    probable_background = np.logical_and(np.logical_and(diff_channel1,diff_channel2), diff_channel3)
        
    if ratio<background_threshold:
        mask[probable_background==1] = cv2.GC_PR_BGD
    
    
    
    mask[0:win_height,0:win_width] = cv2.GC_BGD
    mask[-win_height:-1,-win_width:-1] = cv2.GC_BGD
    mask[0:win_height,-win_width:-1] = cv2.GC_BGD
    mask[-win_height:-1,0:win_width] = cv2.GC_BGD
    
    # boundary bounding
    bound_width = int(min(win_height,win_width)/2)
    print(bound_width)
    mask[1:bound_width,:] = cv2.GC_BGD
    mask[-bound_width:-1,:] = cv2.GC_BGD
    mask[:,1:bound_width,] = cv2.GC_BGD
    mask[:,-bound_width:-1] = cv2.GC_BGD
    
    # return mask
    return mask

# %%
sample = cv2.imread('../../data/temp/2.jpg',cv2.IMREAD_COLOR)
bg = mark_background(sample)
# Out:
# [  95.78127184  104.99231307   88.46750524]
# [ 7.62022228  3.97268724  6.78563172]
# [ 15.24044456   7.94537448  13.57126344]
# 5

# %%
plt.figure(1)
plt.imshow(bg)
# Out:
# <img src="data:image/png;base64,...">

# %%
# Using OpenCV grabcut with obvious background initialization
rect = None

bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

mask, bgdModel, fgdModel = cv2.grabCut(sample,bg,rect,bgdModel,fgdModel,15,cv2.GC_INIT_WITH_MASK)

# %%
plt.figure(2)
plt.imshow(mask)
# Out:
# <img src="data:image/png;base64,...">

# %%
fish = cv2.bitwise_and(sample,sample,mask = (mask==3).astype('uint8'))
plt.figure(3)
plt.imshow(fish)
# Out:
# <img src="data:image/png;base64,...">

# %%
rect = None

bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

path1 = '../../data/seg_images/'
path2 = '../../data/seg_images/'

filenames = next(os.walk(path1))[2]

i = 1
for filename in filenames:
    suffix = filename.rsplit('.', 1)[0]
    filepath = os.path.join(path1,filename)
    img = cv2.imread(filepath,cv2.IMREAD_COLOR)
    
    bg = mark_background(img)
    
    mask, bgdModel, fgdModel = cv2.grabCut(img,bg,rect,bgdModel,fgdModel,15,cv2.GC_INIT_WITH_MASK)
    fish = cv2.bitwise_and(img,img,mask = (mask==3).astype('uint8'))
    
    filepath = os.path.join(path2, suffix + '-fish.png')
    cv2.imwrite(filepath, fish)
    i+=1
# Out:
# /usr/local/lib/python3.4/dist-packages/ipykernel/__main__.py:22: RuntimeWarning: invalid value encountered in true_divide
